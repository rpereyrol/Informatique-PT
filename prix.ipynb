-- %% [markdown]
-- 1. Écrire une requête SQL qui donne pour chaque station : la ville, l'adresse, le type de carburant et le prix correspondant.

-- %%
SELECT ville, adresse, prix_nom, prix_valeur
FROM prix
-- Out:
-- ville	adresse	prix_nom	prix_valeur
-- Saint-Julien-les-Villas	29 BOULEVARD DE DIJON	SP98	1.779
-- Camphin-en-Pévèle	RD 93 GRANDE RUE	E85	0.969
-- BRETTEVILLE-SUR-LAIZE	VARENDES	E10	1.699
-- SENS	Route de Lyon	E10	1.533
-- Achicourt	Rue du 19 Mars 1962	E10	1.608
-- BEAUCOURT	Rue Alfred Péchin	Gazole	1.879
-- AIX-EN-PROVENCE	Avenue de Brédasque	Gazole	1.859
-- AUTERIVE	RN20	E10	1.629
-- Portes-lès-Valence	AUTOROUTE A7 - AIRE PORTE LES VALENCE EST	GPLc	0.814
-- QUETIGNY	AVENUE DE BOURGOGNE	SP98	1.685
-- CUERS	RN 97 Quartier Saint Lazare	E10	1.689
-- Bruges	A630 ROC.PRESQU'ILE LAC COTE2	Gazole	1.914
-- VENDAYS-MONTALIVET	1, Avenue de l'Europe	SP95	1.782
-- SELLIèRES	RUE JEAN MOULIN	Gazole	1.899
-- TAVERNY	CENTRE COMMERCIAL LES PORTES DE TAVERNY	SP98	1.576
-- BARENTIN	Avenue Aristide Briand	SP95	1.686
-- Amboise	21 Avenue de Tours	E10	1.609
-- GENICOURT	CD 916 - ROUTE DE GISORS	E10	1.498
-- VILLENEUVE-LE-ROI	32 Avenue le Foll	Gazole	1.999
-- MENTON	91, route Val des Castagnins	SP95	1.779
-- Malzéville	49 Rue du Colonel Driant	E10	1.733
-- SAINT-SYMPHORIEN-DE-LAY	ZA LA FAYETTE	Gazole	1.849
-- SAINT-MARCEL	Rue du Curtil Canot	SP95	1.82
-- Le Rouget	35 bis Avenue du 15 Septembre 1945	Gazole	1.855
-- Vaudoy-en-Brie	RN4 route de Pecy, lieu dit Lugins	Gazole	2.099
-- Camon	Rue Ambroise Croizat	Gazole	1.895
-- NîMES	120 Chemin du Mas Fléchier	Gazole	1.789
-- Nieul-sur-Mer	LE FIEF ARNAUD	SP98	1.619
-- Annecy	AVENUE DE LA PLAINE	Gazole	1.881
-- MALESTROIT	Avenue de la Gare	SP98	1.759
-- NYONS	31 Avenue de Venterol	Gazole	1.829
-- NYONS	31 Avenue de Venterol	E85	0.739
-- Vic-sur-Cère	ZA DU COMBLAT	Gazole	1.879
-- Attigny	3 Rue Saint-Charles	E85	0.73
-- Castelnaudary	ROUTE DE CARCASSONNE	E85	0.779
-- EPFIG	Lieudit Stotzenweg	SP98	1.829
-- LIMOGES	ZAC Beaubreuil	GPLc	0.699
-- Saint-Germain-lès-Arpajon	RN 20	SP98	1.799
-- Anduze	24 Avenue du Pasteur Rollin	SP98	1.869
-- Antony	18 Rue Jean Moulin	Gazole	1.957
-- Marseille	Route de la Sablière	Gazole	1.859
-- Marseille	Route de la Sablière	E85	0.689
-- Montréjeau	avenue du nord	E10	1.629
-- Le Blanc-Mesnil	60 - 68 PAUL VAILLANT COUTURIER	Gazole	2.109
-- LE MUY	145 RN 7 station total	SP98	1.609
-- Créteil	22 Avenue Pierre Brossolette	SP98	1.786
-- SIGOULèS	le bourg	SP95	1.89
-- Gentilly	67 Avenue Raspail	Gazole	1.909
-- Albaret-Sainte-Marie	Lieudit La Garde D809	E10	1.869
-- Pont-l'Évêque	PARC DU GRIEU - ROUTE DE LISIEUX	E10	1.609
-- ⋮ 	⋮ 	⋮ 	⋮
-- ÉPERNAY	13 Quai de Marne	Gazole	1.919
-- Bourg-en-Bresse	56 Rue du Stand	E85	0.819
-- Étampes	AV DE BONNEVAUX	E10	1.899
-- MIMIZAN	3 route de Baleste	E10	1.648
-- bourgueil	27 avenue du general de gaulle	SP98	1.725
-- MAMERS	ROUTE BELLEME	SP95	1.629
-- COLMAR	10 RTE DE STRASBOURG	GPLc	0.709
-- SAINT-CLéMENT-DE-RIVIèRE	ROUTE DE GANGES	SP98	1.735
-- FIGEAC	15 Avenue Président Georges Pompidou	SP98	1.762
-- L'HORME	38 TER AVENUE PASTEUR	E10	1.65
-- LOUVROIL	Rue Jules Stephenne	SP95	1.695
-- Auch	ROUTE DE TARBES	E10	1.669
-- Auch	ROUTE DE TARBES	SP98	1.749
-- AMBéRIEU-EN-BUGEY	15 Avenue de la Libération	SP95	1.899
-- TREILLIèRES	Rue de Rennes	E85	0.949
-- ST LEGER DE LINIERES	54 Rue de la Liberté	SP95	1.659
-- SAINT-SYMPHORIEN-SUR-COISE	Avenue Emmanuel Clément	E10	1.659
-- MARSEILLE	Centre Commercial Grand Littoral - ZAC Saint-André	SP98	1.72
-- COURTISOLS	2 RUE DENIS PAPIN	E10	1.635
-- GERTWILLER	2 Route de Bourgheim	E10	1.749
-- LA FOUILLOUSE	Avenue Benoit Fourneyron	E10	1.815
-- Le Quesnoy	Centre Commercial Les Portes de l'Avesnois ZAE Ouest	Gazole	1.829
-- CHENERAILLES	Route d'Aubusson	SP98	1.786
-- BELIN-BELIET	10 AVENUE PLANTAGENET	Gazole	1.809
-- Maubert-Fontaine	RN43 Lieu dit Le Pré Meumon	E85	0.739
-- SAINT SEURIN SUR L ISLE	SUPER U 7, RUE DU BARRY NORD	SP95	1.669
-- PORT-DE-BOUC	RN Fos/ Martigues	SP95	1.675
-- LIVRY-GARGAN	2 allée de l est	Gazole	1.999
-- VULBENS	50 chemin des Grands Chavannoux	E10	1.769
-- TERRASSON-LAVILLEDIEU	Zac Le Coutal	E10	1.655
-- MAYENNE	550 Boulevard Jean Monnet	E85	0.869
-- FRANCONVILLE	362 Rue du Général Leclerc	E10	1.599
-- Vienne	14 Cours de Verdun	SP98	1.597
-- MUR-DE-SOLOGNE	341, route de Blois	Gazole	1.88
-- La Bâthie	399 rue de bompan	SP98	1.774
-- Rosporden	Route de Quimper	SP98	1.725
-- Guilberville	ZI le Saussey	SP95	1.799
-- Crécy-sur-Serre	2 AVENUE DE LA LIBERATION	SP98	1.795
-- VANDIèRES	28, rue Charles de Gaulle	E85	0.759
-- BREUILLET	46 route du Magarin	GPLc	0.679
-- Entrains-sur-Nohain	ROUTE DE CLAMECY	E10	1.988
-- Saint-Vincent-de-Paul	RN.124	GPLc	0.637
-- MOULINS-ENGILBERT	PLACE DU CHAMP DE FOIRE	SP95	1.859
-- Romillé	2, RUE DE BROCÉLIANDE	SP95	1.74
-- CHATELLERAULT	Sortie A10 Nord - ZI Nord - Espace d Argenson	E85	0.739
-- SAINT-SULPICE-DE-ROYAN	ROUTE DE ROCHEFORT	E10	1.676
-- Saint-Brieuc	RUE GUILLAUME APOLLINAIRE	GPLc	0.709
-- Sucy-en-Brie	69 Route de la Queue en Brie	Gazole	2.059
-- ARGENTEUIL	193 AVENUE HENRI BARBUSSE	Gazole	1.668
-- SAINT-NICOLAS-DU-PéLEM	CROAS DOM HERRY	SP98	1.699

-- %% [markdown]
-- 2. Écrire une requête SQL qui donne la liste des villes, adresses et prix du sans plomb 95 pour les  stations de Saône-et-Loire. Les trier par prix croissant.

-- %%
SELECT ville, adresse, prix_valeur
FROM prix
WHERE prix_nom="SP95" AND dep_name="Saône-et-Loire"
ORDER BY prix_valeur ASC
-- Out:
-- ville	adresse	prix_valeur
-- DAMEREY	STATION TOTAL RN.73	1.557
-- Boyer	venière	1.59
-- Chagny	19-21 route de Chassagne, RN6	1.609
-- Buxy	1 Rue des Cordiers	1.62
-- Chalon-sur-Saône	6, Rue Paul Sabatier	1.649
-- LUX	27 rue charles dumoulin	1.649
-- Germagny	GRANDE RUE	1.65
-- Saint-Symphorien-de-Marmagne	4413 Route du Morvan	1.654
-- LOUHANS	92 Rue des Bordes	1.659
-- Ouroux-sur-Saône	Rue du Pranet	1.659
-- Mâcon	180 Rue Louise Michel	1.669
-- LOUHANS	Route de Beaufort	1.676
-- Paray-le-Monial	rue de la grande bruyère	1.679
-- Paray-le-Monial	35 QUAI DE L'INDUSTRIE	1.679
-- Saillenard	99 Route de Saint-Germain	1.679
-- SAINT-BONNET-DE-JOUX	Lieu-dit Les Renauds	1.685
-- LE BREUIL	AV DE CHAMBREUIL	1.688
-- PARAY-LE-MONIAL	Parc d'activités de Champ Bossu	1.689
-- Vitry-en-Charollais	le mont	1.689
-- Bourbon-Lancy	6 route de Digoin	1.699
-- SAINT-VALLIER	ZI de la Saule	1.699
-- Chalon-sur-Saône	70 rue des lieutenants chauveau	1.699
-- TOURNUS	AVENUE DE LA RESISTANCE	1.699
-- Chauffailles	Route de Charlieu	1.699
-- Montceau-les-Mines	AVENUE DU MARECHAL LECLERC	1.699
-- GOURDON	Lieu-Dit Beauregard	1.699
-- MONTCHANIN	Avenue des Mouettes	1.701
-- Le Creusot	centre commercial de l arche	1.718
-- DIGOIN	Rue de la Faïencerie	1.719
-- CHAGNY	Rue de Wissen	1.721
-- Étang-sur-Arroux	47 rue Gabriel Bouthiere	1.729
-- Gueugnon	Route de Toulojn sur Arroux	1.749
-- IGORNAY	Le Bourg	1.75
-- CHALON-SUR-SAôNE	144 Avenue de Paris	1.752
-- Chauffailles	1, AVENUE VAN DE WALLE	1.759
-- Perrecy-les-Forges	Avenue Francis Pautonnier	1.769
-- Bourbon-Lancy	47 Avenue Claude et Émile Puzenat	1.789
-- GUEUGNON	ROUTE DE DIGOIN	1.799
-- SAINT-MARCEL	Rue du Curtil Canot	1.82
-- COUCHES	69 RUE SAINT NICOLAS	1.849
-- LA CLAYETTE	Rue des Forges	1.855
-- Varennes-Saint-Sauveur	540 route des CHARMETTES	1.859
-- Saint-Germain-du-Plain	PLACE DU MARCHE	1.859
-- SENNECEY-LE-GRAND	ZA DU CHEMIN FERRE	1.859
-- Montchanin	45 avenue de la République	1.859
-- SAINT-LéGER-SUR-DHEUNE	RUE DE LA GARE	1.859
-- Blanzy	37, rue de la République	1.859
-- BOURBON-LANCY	ROUTE DE MOULINS	1.859
-- Verdun-sur-le-Doubs	AVENUE GISCARD D ESTAING	1.859
-- BUXY	LE CHAMP FLEURY	1.859
-- AUTUN	2 Route de Beaune	1.859
-- TOULON-SUR-ARROUX	ROUTE DE GUEUGNON	1.859
-- BLANZY	RUE DES COMMUNAUTES	1.859
-- SAINT-MARTIN-EN-BRESSE	ROUTE DE LA MADELEINE	1.879
-- MARCIGNY	ZONE ARTISANALE	1.879
-- Charnay-lès-Mâcon	60 Grande Rue de la Coupée	1.879
-- LA CLAYETTE	route des forges	1.889
-- LA CHAPELLE-DE-GUINCHAY	le pré des grandes terres	1.899
-- SAINT-VALLIER	26 Place Roger Salengro	1.899
-- GENELARD	Route de Martigny	1.899
-- CLUNY	AVENUE CHARLES DE GAULLE	1.909
-- SAINT-GENGOUX-LE-NATIONAL	Route de Chalon	1.909
-- BAUGY	Le Champêtre	1.919
-- Romenay	2144 avenue de la gare	1.92
-- CHAROLLES	62 RTE DE MACON	1.929
-- Cluny	14 route de la Digue	1.939
-- Paray-le-Monial	14 Quai du Commerce	1.96

-- %% [markdown]
-- 3. Écrire une requête SQL qui donne les communes et le numéro de département des stations proposant du E85 en Bourgogne-Franche-Comté. On ne veut chaque commune qu'une fois.

-- %%
SELECT DISTINCT com_name, dep_code
FROM prix
WHERE reg_name="Bourgogne-Franche-Comté" AND prix_nom="E85"
-- Out:
-- com_name	dep_code
-- Besançon	25
-- Lure	70
-- Appoigny	89
-- Clux-Villeneuve	71
-- Saint-Amand-en-Puisaye	58
-- Les Rousses	39
-- Mazille	71
-- Précy-sur-Vrin	89
-- Clamecy	58
-- Chalon-sur-Saône	71
-- Brognon	21
-- Dornes	58
-- Romenay	71
-- Villersexel	70
-- Venoy	89
-- Montchanin	71
-- Salins-les-Bains	39
-- Lavans-Quingey	25
-- Saint-André-en-Terre-Plaine	89
-- Autet	70
-- Auxerre	89
-- École-Valentin	25
-- Dijon	21
-- Arc-sur-Tille	21
-- Fourchambault	58
-- Saint-Sauveur	70
-- Cosne-Cours-sur-Loire	58
-- Dole	39
-- Noiron-sous-Gevrey	21
-- Merceuil	21
-- Montmorot	39
-- Villeneuve-sur-Yonne	89
-- Longvic	21
-- Morteau	25
-- Saint-Florentin	89
-- Champagnole	39
-- Genlis	21
-- Tonnerre	89
-- Autun	71
-- Donzy	58
-- Is-sur-Tille	21
-- Sevrey	71
-- Fontaine-Française	21
-- Beaufort-Orbagna	39
-- Malay-le-Grand	89
-- Nevers	58
-- Prissé	71
-- Tavaux	39
-- Charolles	71
-- Dommartin-lès-Cuiseaux	71
-- Toulouse-le-Château	39
-- Châtillon-sur-Seine	21
-- Arbois	39
-- Quetigny	21
-- Varennes-Vauzelles	58
-- Péronne	71
-- Levernois	21
-- Montceau-les-Mines	71
-- Gilly-lès-Cîteaux	21
-- Autechaux	25
-- Ancy-le-Franc	89
-- Vitry-en-Charollais	71
-- Marsannay-la-Côte	21
-- Saint-Désert	71
-- Valdahon	25
-- Guillon-Terre-Plaine	89
-- Monéteau	89
-- Châtenoy-en-Bresse	71
-- Fleurey-sur-Ouche	21
-- Sennecey-lès-Dijon	21
-- Belfort	90
-- Laignes	21
-- Pont-sur-Yonne	89
-- Ligny-le-Châtel	89
-- Vesoul	70
-- Pouilley-les-Vignes	25
-- Rosoy	89
-- Saint-Claude	39
-- Saint-Albain	71
-- Guérigny	58
-- Villeneuve-la-Guyard	89
-- Saint-Bonnet-de-Joux	71
-- Arc-lès-Gray	70
-- Rochefort-sur-Nenon	39
-- Baume-les-Dames	25
-- Sanvignes-les-Mines	71
-- Saône	25
-- La Charité-sur-Loire	58
-- Sochaux	25
-- Dampierre-les-Bois	25
-- La Machine	58
-- Coulanges-lès-Nevers	58
-- Foncine-le-Haut	39
-- Perrecy-les-Forges	71
-- Lavancia-Epercy	39
-- Marchaux-Chaudefontaine	25
-- Courcelles-lès-Montbéliard	25
-- Toucy	89
-- Charny Orée de Puisaye	89
-- Devecey	25
-- Navenne	70
-- Crêches-sur-Saône	71
-- Épineau-les-Voves	89
-- Orgelet	39
-- Decize	58
-- Issy-l'Évêque	71
-- Migennes	89
-- Cuisery	71
-- Quingey	25
-- Semur-en-Auxois	21
-- Magny-Cours	58
-- Beaune	21
-- Pusey	70

-- %% [markdown]
-- 4. Écrire une requête SQL qui donne la liste des villes où on trouve du E10 à un prix supérieur à $2$ € par litre. Trier par ordre alphabétique.

-- %%
SELECT DISTINCT ville
FROM prix
WHERE prix_nom="E10" AND prix_valeur>=2
ORDER BY ville
-- Out:
-- ville
-- AILLAS
-- AVRAINVILLE
-- BOUZONVILLE
-- Bièvres
-- Boissy saint léger
-- CESTAS
-- CHAUMONT-SUR-THARONNE
-- Champlan
-- Charenton-le-Pont
-- Fos-sur-Mer
-- GENNEVILLIERS
-- LA MEMBROLLE-SUR-CHOISILLE
-- Lamotte-Beuvron
-- MALAKOFF
-- MAULETTE
-- MONTROUGE
-- Maulette
-- Meunet-sur-Vatan
-- NOIRéTABLE
-- ORLY
-- PARIS
-- Paris
-- Rueil-Malmaison
-- SAINT-MANDé
-- ST MAUR DES FOSSES
-- Sailly-Flibeaucourt
-- Saint-Jeoire-Prieuré
-- Saint-Laurent-du-Var
-- Saint-Léger
-- Saint-Sylvain-d'Anjou
-- Seclin
-- Sorèze
-- Theillay
-- VAUCRESSON
-- VITRAC-SUR-MONTANE
-- Vaudoy-en-Brie

-- %% [markdown]
-- 5. Écrire une requête SQL qui renvoie les $10$ stations les plus chères de France en gazole hors Paris, les trier par prix décroissant.

-- %%
SELECT ville, adresse
FROM prix
WHERE prix_nom="Gazole" AND com_name<>"Paris"
ORDER BY prix_valeur DESC
LIMIT 10
-- Out:
-- ville	adresse
-- L'Île-d'Yeu	9 Rue Neptune
-- Château-ville-vieille	RN 547
-- Florac	65 AVENUE JEAN MONESTIER
-- Saint-Ouen	23 Boulevard Victor Hugo
-- Saint-Laurent-du-Var	526 ROUTE DES VESPINS (RN7)
-- Fos-sur-Mer	215 avenue Georges Pompidou
-- OPIO	20 Route de Cannes
-- Eze	35 avenue de Verdun
-- Meunet-sur-Vatan	A20 AIRE DES CHAMPS D' AMOUR
-- MONTROUGE	70-74 AV ARISTIDE BRIAND

-- %% [markdown]
-- 1. Écrire une requête SQL qui renvoie le prix moyen en France pour chaque carburant ; nommer « prix moyen » la colonne de prix.

-- %%
SELECT prix_nom,AVG(prix_valeur) AS "prix moyen"
FROM prix
GROUP BY prix_nom
ORDER BY "prix moyen"
-- Out:
-- prix_nom	prix moyen
-- GPLc	0.7789049808429119
-- E85	0.8168190934616927
-- E10	1.6604637992831544
-- SP95	1.721477980035232
-- SP98	1.7648063967335827
-- Gazole	1.8629531287750665

-- %% [markdown]
-- 2. Écrire une requête SQL qui renvoie le prix maximal du sans plomb 98 par région.

-- %%
SELECT reg_name,MAX(prix_valeur)
FROM prix
WHERE prix_nom="SP98"
GROUP BY reg_name
-- Out:
-- reg_name	MAX(prix_valeur)
-- Auvergne-Rhône-Alpes	2.29
-- Bourgogne-Franche-Comté	2.139
-- Bretagne	1.959
-- Centre-Val de Loire	2.259
-- Grand Est	2.112
-- Hauts-de-France	2.126
-- Normandie	2.089
-- Nouvelle-Aquitaine	2.179
-- Occitanie	2.418
-- Pays de la Loire	2.149
-- Provence-Alpes-Côte d'Azur	2.749
-- Île-de-France	2.78

-- %% [markdown]
-- 3. Écrire une requête SQL qui renvoie les 20 stations où l'écart entre le carburant le plus cher et le moins cher est le plus grand.

-- %%
SELECT adresse, ville, MAX(prix_valeur)-MIN(prix_valeur) AS ecart
FROM prix
GROUP BY id
ORDER BY ecart DESC
LIMIT 20
-- Out:
-- adresse	ville	ecart
-- Avenue Georges Pompidou	Fos-sur-Mer	2.0100000000000002
-- RN12 E12-LE VAL RAYMOND	Maulette	1.562
-- SARL Jaby, ORLY Ouest 453	ORLY	1.5
-- 55 Av du général Leclerc	Boissy saint léger	1.5
-- 32 AV DE ROSNY	VILLEMOMBLE	1.4900000000000002
-- 70 Avenue Roger Salengro	CALAIS	1.4469999999999998
-- 16 ROUTE DE CHANTILLY LA PIERRE BLANCHE	CREIL	1.4269999999999998
-- ROUTE DE CLERMONT D 978	CHAMPEIX	1.4189999999999998
-- Autoroute A71, Sens Paris-Vierzon	Theillay	1.4140000000000001
-- 73 Avenue de Paris	Vernon	1.41
-- RUE AMBROISE CROIZAT	Sin-le-Noble	1.408
-- 114 Rue de Paris	Charenton-le-Pont	1.4
-- 64 AVENUE FOCH	ST MAUR DES FOSSES	1.4
-- VOIE EXPRESS CD 117	Massy	1.4
-- RN4 route de Pecy, lieu dit Lugins	Vaudoy-en-Brie	1.4
-- A20 AIRE DES CHAMPS D' AMOUR	Meunet-sur-Vatan	1.39
-- 162 Route de Rennes	Nantes	1.3789999999999998
-- AUTOROUTE A 71	CHAUMONT-SUR-THARONNE	1.375
-- 97/99 Avenue du docteur Morel	ARLES	1.3719999999999999
-- 91 Avenue Aristide Briand	MONTROUGE	1.37

-- %% [markdown]
-- 4. Écrire une requête SQL qui renvoie la liste des stations qui proposent au plus deux carburants (il y a pénurie !)

-- %%
SELECT ville, adresse
FROM prix
GROUP BY id
HAVING COUNT(prix_nom)<=2
-- Out:
-- ville	adresse
-- SAINT-DENIS-LèS-BOURG	596 AVENUE DE TREVOUX
-- TROYES	17, BLD GEORGES POMPIDOU
-- BOURG-EN-BRESSE	16 Avenue de Marboz
-- Romilly-sur-Seine	AVENUE DIDEROT
-- Romilly-sur-Seine	123 Rue Aristide Briand
-- Saint-Germain	184 Route Nationale 77 - Chevillele
-- Saint-André-les-Vergers	Avenue Charles de Refuge
-- VENDEUVRE-SUR-BARSE	5 RUE DES TANNERIES
-- MERY-SUR-SEINE	ROUTE D ARCIS
-- ESTISSAC	AVENUE DE LA REPUBLIQUE
-- BAR-SUR-AUBE	Rue Louis Desprez
-- Bar-sur-Aube	Faubourg de Belfort
-- CHAOURCE	13 route de Troyes
-- Mailly-le-Camp	RN 7
-- VAUDES	RD185 LES GRANDES FOSSES
-- Lusigny-sur-Barse	29 Avenue Pierre Gomand
-- Sainte-Savine	82 AVENUE DU GENERAL LECLERC
-- Sainte-Savine	Boulevard de l'Ouest
-- La Chapelle-Saint-Luc	118 Avenue du Général Sarrail
-- Buchères	1 ROUTE DE MAISONS BLANCHES
-- MONTCEAUX	1 ROUTE DE FRANCHELEINS
-- OYONNAX	Rue Brillat-Savarin
-- OYONNAX	174 COURS DE VERDUN
-- Narbonne	Avenue de la Croix Sud - PL uniquement
-- NARBONNE	60AVENUE DU GENERAL LECLERC
-- NARBONNE	82 AVENUE CARNOT
-- Salles-d'Aude	Route de Coursan
-- AXAT	Lieu Dit La Condomine
-- HOMPS	ROUTE DEPARTEMENTALE 610
-- LA BOISSE	Route de Thil
-- La Boisse	521 ROUTE NATIONALE
-- Rouffiac d'Aude	100 chemin de la plaine, station service total
-- LIMOUX	59 avenue de Catalogne
-- Castelnaudary	ROUTE DE CARCASSONNE
-- CASTELNAUDARY	1033 Avenue Martin dauch
-- Quillan	Place de la Liberté
-- LAGNIEU	8 RUE DE L'INDUSTRIE
-- ROQUEFORT-DES-CORBIèRES	ROUTE NATIONALE 9
-- VILLEGLY	RD 620 Lieu dit la pièce
-- Pont-d'Ain	RTE DE BOURG RN 75
-- GEX	Lieu-Dit les Vertes Campagnes
-- Gex	Route de Divonne les Bains
-- RODEZ	ROUTE D'ESPALION
-- Rodez	33 Bd Paul ramadier
-- RODEZ	18 AVENUE DU SÉGALA
-- Bellegarde-sur-Valserine	Avenue Maréchal de Lattre de Tassigny
-- Millau	144 Avenue Jean Jaurès
-- FERNEY-VOLTAIRE	Route de Meyrin
-- Viviez	Zone de Laubarède
-- Viviez	41ter Avenue Adam Grange
-- ⋮ 	⋮
-- Les Pavillons-sous-Bois	262 AVENUE ARISTIDE BRIAND
-- Neuilly-sur-Marne	29-33 BLD DU MARECHAL FOCH
-- Neuilly-Plaisance	3 CHEMIN DE MEAUX
-- Saint-Ouen	23 Boulevard Victor Hugo
-- Saint-Ouen	56-74 AVENUE MICHELET
-- Saint-Ouen	41 RUE ALBERT DHALENNE
-- DUGNY	226-232 AVENUE DU 8 MAI 1945
-- COUBRON	ZAC DES PRES CD N° 136
-- AULNAY-SOUS-BOIS	32 Rue Jacques Duclos
-- Aulnay-sous-Bois	BLD MARC CHAGALL
-- Épinay-sur-Seine	53 ROUTE DE SAINT LEU
-- Saint-Maur-des-Fossés	57 BD DE CRETEIL
-- Arcueil	23 Avenue Paul Doumer
-- Fontenay-sous-Bois	236 Avenue de la République
-- Le Perreux-sur-Marne	264 Avenue du Général de Gaulle
-- Ivry-sur-Seine	168-180 BLD DE STALINGRAD
-- Joinville-le-Pont	39 RUE CHAPSAL
-- JOINVILLE LE PONT	17/19 BD DE L'EUROPE
-- Sucy-en-Brie	69 Route de la Queue en Brie
-- Sucy-en-Brie	63/71 AV DU GENERAL LECLERC
-- CHENNEVIERES SUR MARNE	79 RUE DES FUSILLES DE CHATEAUBR
-- Limeil-Brévannes	1 BIS AV GABRIEL PERI
-- Boissy-Saint-Léger	36 Avenue du Général Leclerc
-- CHAMPIGNY SUR MARNE	114 AV. DU GENERAL DE GAULLE
-- Chevilly-Larue	14 AV DU GENERAL DE GAULLE
-- RUNGIS CEDEX	RUE DU VIADUC
-- Argenteuil	RN 311 QUAI ST DENIS
-- ARGENTEUIL	RUE JACQUES BREL
-- ARGENTEUIL	RUE DES GRIVES - ZAC FOSSE AUX L
-- ARGENTEUIL	8 R DES MARTYRS CHATEAUBRIANT
-- HERBLAY	34, AV. DE LA LIBERATION
-- Soisy-sous-Montmorency	59 Avenue Kellermann
-- Soisy-sous-Montmorency	20 AV.DE PARIS
-- SOISY SOUS MONTMORENCY	63 AVENUE DE PARIS
-- Jouy-le-Moutier	Les versants de l'Hautil
-- L'ISLE-ADAM	BOULEVARD TILSIT
-- Saint-Ouen-l'Aumône	RN 184 - ZI VERT GALANT
-- Saint-Leu-la-Forêt	Boulevard André Brémond
-- MONTIGNY-LES-CORMEILLES	211 Boulevard de Pontoise
-- Villiers-le-Bel	AVENUE DES ERABLES
-- MAGNY-EN-VEXIN	route de rouen
-- Écouen	56 Rue de la Libération
-- ÉCOUEN	Route Nationale 16
-- La Chapelle-en-Serval	RD922
-- PIERRELAYE	AUTOROUTE A15 - AIRE DE PIERRELAYE
-- GONESSE	RD 370 RUE NUNGESSER ET COLI
-- OSNY	chemin du Poirier Charles Guérin
-- OSNY	LIEUDIT LE CHAMP POURRI CD 915
-- EAUBONNE	48 AVENUE KELLERMANN
-- Roissy-en-France	1 RUE DE L'OR - BP.20212

-- %% [markdown]
-- 5. Écrire une requête SQL qui renvoie la liste des départements où le prix moyen du gazole est supérieur à la moyenne nationale.

-- %%
SELECT DISTINCT(dep_name)
FROM prix
WHERE prix_nom="Gazole" 
GROUP BY dep_name
HAVING AVG(prix_valeur)>= (SELECT AVG(prix_valeur) FROM prix WHERE prix_nom="Gazole")
-- Out:
-- dep_name
-- Aisne
-- Allier
-- Alpes-Maritimes
-- Ardennes
-- Aube
-- Cantal
-- Cher
-- Corrèze
-- Creuse
-- Côte-d'Or
-- Dordogne
-- Doubs
-- Essonne
-- Eure-et-Loir
-- Haute-Marne
-- Haute-Savoie
-- Haute-Saône
-- Haute-Vienne
-- Hautes-Pyrénées
-- Hauts-de-Seine
-- Indre
-- Indre-et-Loire
-- Jura
-- Landes
-- Loir-et-Cher
-- Loiret
-- Lot
-- Lozère
-- Marne
-- Meurthe-et-Moselle
-- Meuse
-- Moselle
-- Nièvre
-- Oise
-- Orne
-- Paris
-- Sarthe
-- Savoie
-- Saône-et-Loire
-- Seine-Saint-Denis
-- Seine-et-Marne
-- Somme
-- Territoire de Belfort
-- Val-d'Oise
-- Val-de-Marne
-- Vosges
-- Yonne
-- Yvelines
